# %%
from classy import Class
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
params={'H0':75, 'T_cmb':2.7255,
        'Omega_b':0.05,'Omega_cdm':0.25, 'Omega_k':0.0, 'Omega_Lambda':0.0, 'Omega_fld':0.0,
       'Omega_scf': -1, 'attractor_ic_scf':'no', 'scf_parameters':'8,2,0.01,34.8,34.8,10**(44)' , 'scf_tuning_index':0.0}
#params2 = {'H0':75, 'T_cmb':2.7255,
#        'Omega_b':0.05,'Omega_cdm':0.25, 'Omega_k':0.0, 'Omega_Lambda':0.0, 'Omega_fld':0.0,
#       'Omega_scf': -1, 'attractor_ic_scf':'no', 'scf_parameters':'8,2,0.01,34.8,100,10' , 'scf_tuning_index':0.0}

# %%
QCDM = Class()
QCDM.set(params)
QCDM.compute()
#qcdm2 = Class()
#qcdm2.set(params2)
#qcdm2.compute()

# %%
#lensed_cl = QCDM.lensed_cl(10**3)
#lensed_cl.viewkeys()
bgQCDM = QCDM.get_background()
#bgqcdm2 = qcdm2.get_background()
bgQCDM.viewkeys()
# Out:
# dict_keys(['(.)rho_crit', 'V_scf', '(.)p_scf', '(.)p_tot_prime', '(.)rho_cdm', 'phi_scf', '(.)rho_ur', '(.)rho_tot', '(.)p_prime_scf', 'ang.diam.dist.', 'proper time [Gyr]', "V'_scf", 'H [1/Mpc]', 'conf. time [Mpc]', '(.)p_tot', 'lum. dist.', "V''_scf", 'gr.fac. f', '(.)rho_scf', 'comov. dist.', 'comov.snd.hrz.', '(.)rho_b', '(.)rho_g', 'gr.fac. D', "phi'_scf", 'z'])

# %%
zlist = bgQCDM['z']
#zzlist = zlist[0:zlist.size-1]
#aalist = 1/(zzlist +1)
#alist = np.append(aalist,1)
alist = 1/(zlist + 1)

# %%
plt.loglog(bgQCDM['z'], bgQCDM['(.)rho_crit'],bgQCDM['z'],bgQCDM['(.)rho_scf'],bgQCDM['z'],bgQCDM['(.)rho_cdm'])
# Out:
# [<matplotlib.lines.Line2D at 0x129d6eb90>,
#  <matplotlib.lines.Line2D at 0x12aae23d0>,
#  <matplotlib.lines.Line2D at 0x12aae2810>]

# %%
plt.loglog(alist, bgQCDM['(.)rho_crit'], alist,bgQCDM['(.)rho_scf'],alist,bgQCDM['(.)rho_cdm'])
# Out:
# [<matplotlib.lines.Line2D at 0x12abc8d10>,
#  <matplotlib.lines.Line2D at 0x129fbe590>,
#  <matplotlib.lines.Line2D at 0x129fbe9d0>]

# %%
plt.loglog(alist, np.abs(bgQCDM['(.)p_scf']), alist, bgQCDM['(.)rho_scf'])
# Out:
# [<matplotlib.lines.Line2D at 0x12a5e1690>,
#  <matplotlib.lines.Line2D at 0x12a606290>]

# %%
val = 600
print(alist[val],bgQCDM['V_scf'][val],bgQCDM['phi_scf'][val],bgQCDM["phi'_scf"][val])
# Out:
# (6.571769646831835e-13, 1.3142552695104703e-07, 34.80000004564376, 0.002315449618319517)

# %%
print(alist[3300],bgQCDM['(.)rho_scf'][3300])
print(alist[3300],bgQCDM['(.)p_scf'][3300])
# Out:
# (9.942770193219863e-05, 4.3808508973707976e-08)
# (9.942770193219863e-05, -4.3808508973707605e-08)

# %%
plt.semilogx(alist[4200:], bgQCDM["phi_scf"][4200:])

# %%
plt.semilogx(alist[4200:], (bgQCDM['(.)p_scf']/bgQCDM['(.)rho_scf'])[4200:])

# %%
plt.plot(bgQCDM['phi_scf'],bgQCDM['V_scf'])
print(bgQCDM['phi_scf'][4619])
# Out:
# 34.80156618173355

# %%
zlist2 = bgqcdm2['z']
alist2 = 1/(zlist2 + 1)
plt.loglog(alist2, bgqcdm2['(.)rho_scf'],alist, bgQCDM['(.)rho_scf'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-189-5ecde969c52c> in <module>()
# ----> 1 zlist2 = bgqcdm2['z']
#       2 alist2 = 1/(zlist2 + 1)
#       3 plt.loglog(alist2, bgqcdm2['(.)rho_scf'],alist, bgQCDM['(.)rho_scf'])
#
# NameError: name 'bgqcdm2' is not defined

# %%
plt.semilogx(alist, bgqcdm2['(.)p_scf']/bgqcdm2['(.)rho_scf'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-0d3a784de49c> in <module>()
# ----> 1 plt.semilogx(alist, bgqcdm2['(.)p_scf']/bgqcdm2['(.)rho_scf'])
#
# NameError: name 'bgqcdm2' is not defined

# %%
plt.loglog(alist, bgqcdm2['(.)rho_crit'], alist,bgqcdm2['(.)rho_scf'],alist,bgqcdm2['(.)rho_cdm'], alist,bgqcdm2['(.)rho_g'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-183165b628eb> in <module>()
# ----> 1 plt.loglog(alist, bgqcdm2['(.)rho_crit'], alist,bgqcdm2['(.)rho_scf'],alist,bgqcdm2['(.)rho_cdm'], alist,bgqcdm2['(.)rho_g'])
#
# NameError: name 'bgqcdm2' is not defined

# %%
plt.semilogx(alist2, bgqcdm2["phi_scf"])

# %%
#qcdm2.struct_cleanup()
#qcdm2.empty()
QCDM.struct_cleanup()
QCDM.empty()

# %%
bgqcdm2["(.)p_prime_scf"][4619]
# Out:
# 3.298056594020753e-13

# %%
plt.semilogx(alist, bgQCDM['(.)rho_scf']/bgQCDM['(.)rho_crit'],
             alist, (bgQCDM['(.)rho_g']+bgQCDM['(.)rho_ur'])/bgQCDM['(.)rho_crit'],
             alist, (bgQCDM['(.)rho_cdm']+bgQCDM['(.)rho_b'])/bgQCDM['(.)rho_crit'])
# Out:
# [<matplotlib.lines.Line2D at 0x1253c0190>,
#  <matplotlib.lines.Line2D at 0x1253f04d0>,
#  <matplotlib.lines.Line2D at 0x1253f0910>]

# %%
l = np.array(range(2,10**3 + 1))
factor = l*(l+1)/(2*np.pi)
plt.loglog(l,factor*10**(12)*lensed_cl['tt'][2:])
# Out:
# ---------------------------------------------------------------------------
# CosmoSevereError                          Traceback (most recent call last)
# <ipython-input-116-5d372fd98321> in <module>()
#       1 l = np.array(range(2,10**3 + 1))
#       2 factor = l*(l+1)/(2*np.pi)
# ----> 3 lensedCl = QCDM.lensed_cl(10**3)
#       4
#       5
#
# classy.pyx in classy.Class.lensed_cl()
#
# CosmoSevereError:
#
# Error in Class: No lensed Cl computed
